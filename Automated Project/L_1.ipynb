# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Title: Small Business Website Development
#
# ### Objective:
# To create a functional, visually appealing, and responsive website for a small business that effectively communicates the brand's messaging, offerings, and encourages user interaction.
#
# ### Comprehensive Task Breakdown:
#
# #### 1. **Project Kickoff**
#    - **Description:** Initial meeting with all team members to discuss goals, timelines, and deliverables.
#    - **Timeline:** Day 1
#    - **Dependencies:** None
#    - **Deliverable:** Project charter and communication plan.
#
# #### 2. **Gather Requirements**
#    - **Description:** Detailed discussions with the business owner to understand needs and preferences. Document functional and non-functional requirements.
#    - **Timeline:** Days 2-3
#    - **Dependencies:** Project kickoff
#    - **Deliverable:** Requirements specification document.
#
# #### 3. **Create Wireframes**
#    - **Description:** Design low-fidelity wireframes for the key pages (Homepage, About Us, Services, Contact Us, Blog, Testimonials).
#    - **Timeline:** Days 4-6
#    - **Dependencies:** Requirements gathering
#    - **Deliverable:** Set of wireframes for review.
#
# #### 4. **Design UI/UX**
#    - **Description:** Transform wireframes into high-fidelity UI designs, ensuring a modern and clean aesthetic.
#    - **Timeline:** Days 7-14
#    - **Dependencies:** Approved wireframes
#    - **Deliverable:** High-fidelity mockups for review.
#
# #### 5. **Develop Website Structure**
#    - **Description:** Set up the website’s architecture including responsive design implementation for different devices.
#    - **Timeline:** Days 15-18
#    - **Dependencies:** Approved UI/UX designs
#    - **Deliverable:** Website skeleton.
#
# #### 6. **Coding the Frontend**
#    - **Description:** Implement the visual elements of the website using HTML, CSS, and JavaScript.
#    - **Timeline:** Days 19-30
#    - **Dependencies:** Developed website structure
#    - **Deliverable:** Functional frontend for stakeholder testing.
#
# #### 7. **Back-end Development**
#    - **Description:** Integrate CMS for blog and services page, implement forms for "Contact Us", and set up database connections.
#    - **Timeline:** Days 31-40
#    - **Dependencies:** Completed frontend
#    - **Deliverable:** Backend logic and database functionality.
#
# #### 8. **User Navigation System Development**
#    - **Description:** Create an intuitive menu structure that allows easy navigation across the website.
#    - **Timeline:** Days 41-45
#    - **Dependencies:** Completed frontend
#    - **Deliverable:** Functional menu and navigation framework.
#
# #### 9. **SEO and Fast Loading Time Optimization**
#    - **Description:** Implement SEO best practices and optimize images and scripts to ensure fast loading times.
#    - **Timeline:** Days 46-50
#    - **Dependencies:** Completed website
#    - **Deliverable:** SEO optimized website ready for launch.
#
# #### 10. **Social Media Integration**
#    - **Description:** Add social media widgets and links for sharing content and building audience engagement.
#    - **Timeline:** Day 51
#    - **Dependencies:** Completed website
#    - **Deliverable:** Social media integrated website.
#
# #### 11. **Quality Assurance Testing**
#    - **Description:** Conduct thorough testing for usability, performance, and cross-browser compatibility.
#    - **Timeline:** Days 52-56
#    - **Dependencies:** Completed website
#    - **Deliverable:** QA report with findings and fixes.
#
# #### 12. **Client Review & Feedback**
#    - **Description:** Present the website to the client for review and collect feedback.
#    - **Timeline:** Days 57-58
#    - **Dependencies:** Completed QA tests
#    - **Deliverable:** Feedback and revision requests.
#
# #### 13. **Final Revisions**
#    - **Description:** Implement revisions based on client feedback.
#    - **Timeline:** Days 59-61
#    - **Dependencies:** Client review & feedback
#    - **Deliverable:** Finalized website.
#
# #### 14. **Deployment & Launch**
#    - **Description:** Move site to live server and ensure all functionalities are working correctly.
#    - **Timeline:** Day 62
#    - **Dependencies:** Final revisions
#    - **Deliverable:** Live website.
#
# #### 15. **Post-Launch Support and Maintenance**
#    - **Description:** Monitor site performance, address any post-launch issues, and provide regular updates.
#    - **Timeline:** Ongoing for 1 month post-launch
#    - **Dependencies:** Launch of website
#    - **Deliverable:** Maintenance plan and reports.
#
# ### Gantt Chart Visualization
#
# ```plaintext
# | Task                          | Duration     | Timeline         |
# |-------------------------------|--------------|-------------------|
# | Project Kickoff               | 1 day       | Day 1             |
# | Gather Requirements            | 2 days      | Days 2-3          |
# | Create Wireframes             | 3 days      | Days 4-6          |
# | Design UI/UX                  | 8 days      | Days 7-14         |
# | Develop Website Structure      | 4 days      | Days 15-18        |
# | Coding the Frontend           | 12 days     | Days 19-30        |
# | Back-end Development           | 10 days     | Days 31-40        |
# | User Navigation Development     | 5 days      | Days 41-45        |
# | SEO and Optimization           | 5 days      | Days 46-50        |
# | Social Media Integration       | 1 day       | Day 51            |
# | Quality Assurance Testing      | 5 days      | Days 52-56        |
# | Client Review & Feedback      | 2 days      | Days 57-58        |
# | Final Revisions               | 3 days      | Days 59-61        |
# | Deployment & Launch           | 1 day       | Day 62            |
# | Post-Launch Support and Maintenance | Ongoing | 1 month post-launch|
# ```
#
# ### Team Members Responsibilities:
# - **John Doe (Project Manager):** Oversees project timeline, communication, and stakeholder management.
# - **Jane Doe (Software Engineer):** Responsible for frontend and backend development.
# - **Bob Smith (Designer):** Creates wireframes and UI/UX designs.
# - **Alice Johnson & Tom Brown (QA Engineers):** Conduct testing and quality assurance.
#
# ### Expected Outcome:
# The project will result in a fully functional, responsive website that enhances the small business’s online presence, improves user engagement, and facilitates easy communication with customers. The structured approach ensures all details are meticulously planned and delivered on time.
#
# This comprehensive plan lays out a clear roadmap to the successful completion of the website project, with specific tasks, responsibilities, and timelines that align with the project's goals.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Small Business Website Development
#
# #### Overview
# This report provides a comprehensive evaluation of tasks for the Small Business Website Development project. Each task includes estimations of the time, resources, and effort necessary to achieve the objectives outlined in the project scope. Additionally, risks and uncertainties associated with the estimations are summarized.
#
# #### Task Breakdown and Estimations
#
# 1. **Project Kickoff**
#    - **Time Required:** 1 day
#    - **Resources Needed:** Project Manager (John Doe)
#    - **Effort:** 4 hours
#    - **Risks/Uncertainties:** None.
#
# 2. **Gather Requirements**
#    - **Time Required:** 2 days
#    - **Resources Needed:** Project Manager (John Doe), Business Owner
#    - **Effort:** 16 hours
#    - **Risks/Uncertainties:** Possible ambiguity in requirements leading to rework.
#
# 3. **Create Wireframes**
#    - **Time Required:** 3 days
#    - **Resources Needed:** Designer (Bob Smith)
#    - **Effort:** 24 hours
#    - **Risks/Uncertainties:** Delay if feedback on wireframes is slow.
#
# 4. **Design UI/UX**
#    - **Time Required:** 8 days
#    - **Resources Needed:** Designer (Bob Smith)
#    - **Effort:** 64 hours
#    - **Risks/Uncertainties:** Potential misalignment between designs and client expectations.
#
# 5. **Develop Website Structure**
#    - **Time Required:** 4 days
#    - **Resources Needed:** Software Engineer (Jane Doe)
#    - **Effort:** 32 hours
#    - **Risks/Uncertainties:** Configuration issues with responsive design implementation.
#
# 6. **Coding the Frontend**
#    - **Time Required:** 12 days
#    - **Resources Needed:** Software Engineer (Jane Doe)
#    - **Effort:** 96 hours
#    - **Risks/Uncertainties:** May face unexpected complexities in implementation.
#
# 7. **Back-end Development**
#    - **Time Required:** 10 days
#    - **Resources Needed:** Software Engineer (Jane Doe)
#    - **Effort:** 80 hours
#    - **Risks/Uncertainties:** Database connection issues or CMS integration challenges.
#
# 8. **User Navigation System Development**
#    - **Time Required:** 5 days
#    - **Resources Needed:** Software Engineer (Jane Doe)
#    - **Effort:** 40 hours
#    - **Risks/Uncertainties:** User experience might not meet usability standards if not adequately tested.
#
# 9. **SEO and Fast Loading Time Optimization**
#    - **Time Required:** 5 days
#    - **Resources Needed:** Software Engineer (Jane Doe)
#    - **Effort:** 40 hours
#    - **Risks/Uncertainties:** Changes in SEO guidelines may affect the implementation timeline.
#
# 10. **Social Media Integration**
#     - **Time Required:** 1 day
#     - **Resources Needed:** Software Engineer (Jane Doe)
#     - **Effort:** 8 hours
#     - **Risks/Uncertainties:** Social media platform updates may affect integration success.
#
# 11. **Quality Assurance Testing**
#     - **Time Required:** 5 days
#     - **Resources Needed:** QA Engineers (Alice Johnson & Tom Brown)
#     - **Effort:** 80 hours total (40 hours each)
#     - **Risks/Uncertainties:** Hidden bugs may cause delays in project timeline.
#
# 12. **Client Review & Feedback**
#     - **Time Required:** 2 days
#     - **Resources Needed:** Project Manager (John Doe), Business Owner
#     - **Effort:** 16 hours
#     - **Risks/Uncertainties:** Feedback may require multiple iterations, potentially causing rework.
#
# 13. **Final Revisions**
#     - **Time Required:** 3 days
#     - **Resources Needed:** Software Engineer (Jane Doe), Designer (Bob Smith)
#     - **Effort:** 24 hours total (12 hours each)
#     - **Risks/Uncertainties:** Client requests could increase time duration drastically.
#
# 14. **Deployment & Launch**
#     - **Time Required:** 1 day
#     - **Resources Needed:** Software Engineer (Jane Doe)
#     - **Effort:** 8 hours
#     - **Risks/Uncertainties:** Issues during the launch phase could lead to a disruption in service.
#
# 15. **Post-Launch Support and Maintenance**
#     - **Time Required:** Ongoing for 1 month
#     - **Resources Needed:** Software Engineer (Jane Doe)
#     - **Effort:** Estimated 40 hours for the month
#     - **Risks/Uncertainties:** Additional post-launch issues may arise requiring more resources.
#
# ### Summary of Estimations
# - **Total Estimated Effort:** 493 hours across all tasks.
# - **Team Composition:**
#   - 1 Project Manager
#   - 1 Software Engineer
#   - 1 Designer
#   - 2 QA Engineers
#
# ### Risks and Uncertainties Summary
# The project timeline and estimations are affected by several risks, including unforeseen feedback loops from the client, potential technical issues during development, and market changes affecting SEO practices. Close attention to communication and regular status updates will mitigate most of these risks.
#
# ### Expected Outcome
# The project is structured to deliver a fully functional and visually appealing website aligned with the small business's branding and objectives. The emphasis on thorough testing and quality assurance will maximize client satisfaction and minimize post-launch issues.
#
# This detailed report ensures a systematic approach to meeting project goals while maintaining a focus on efficiency and budget adherence.
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                               | Assigned Team Member(s)        | Start Date | End Date   | Duration  |
# |------------------------------------|---------------------------------|------------|------------|-----------|
# | Project Kickoff                    | John Doe                        | MM/DD/YYYY | MM/DD/YYYY | 1 day     |
# | Gather Requirements                 | John Doe                        | MM/DD/YYYY | MM/DD/YYYY | 2 days    |
# | Create Wireframes                  | Bob Smith                       | MM/DD/YYYY | MM/DD/YYYY | 3 days    |
# | Design UI/UX                      | Bob Smith                       | MM/DD/YYYY | MM/DD/YYYY | 8 days    |
# | Develop Website Structure          | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 4 days    |
# | Coding the Frontend                | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 12 days   |
# | Back-end Development                | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 10 days   |
# | User Navigation System Development  | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 5 days    |
# | SEO and Fast Loading Time Optimization | Jane Doe                    | MM/DD/YYYY | MM/DD/YYYY | 5 days    |
# | Social Media Integration            | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 1 day     |
# | Quality Assurance Testing           | Alice Johnson, Tom Brown       | MM/DD/YYYY | MM/DD/YYYY | 5 days    |
# | Client Review & Feedback            | John Doe                        | MM/DD/YYYY | MM/DD/YYYY | 2 days    |
# | Final Revisions                    | Jane Doe, Bob Smith            | MM/DD/YYYY | MM/DD/YYYY | 3 days    |
# | Deployment & Launch                | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 1 day     |
# | Post-Launch Support and Maintenance | Jane Doe                        | MM/DD/YYYY | MM/DD/YYYY | 1 month   |
#
# ### Rationale Behind Each Allocation Decision:
#
# 1. **Project Kickoff**: John Doe, as the Project Manager, leads this initiative to establish project objectives and key milestones, requiring only 1 day and 4 hours of effort.
#
# 2. **Gather Requirements**: John Doe is also tasked here as he is essential in driving the discussion with the Business Owner to clarify project needs, ensuring no ambiguity.
#
# 3. **Create Wireframes**: Bob Smith, the Designer, takes on the wireframe creation, which is a creative task that aligns directly with his design expertise and requires 24 hours over 3 days.
#
# 4. **Design UI/UX**: Bob Smith continues his involvement for 8 days to develop a cohesive design that captures the client’s vision, requiring extensive feedback loops.
#
# 5. **Develop Website Structure**: Jane Doe is the ideal candidate for developing the website structure due to her technical skills as a Software Engineer, evidenced by the 4-day timeline.
#
# 6. **Coding the Frontend**: Jane's skills are once again leveraged for frontend coding over 12 days, acknowledging her previous experience and anticipated complexities.
#
# 7. **Back-end Development**: Jane continues onto backend development, utilizing her software knowledge to establish robust functionality over 10 days.
#
# 8. **User Navigation System Development**: Jane is responsible for the user navigation as it requires continuity in the coding environment and is crucial for user experience.
#
# 9. **SEO and Fast Loading Time Optimization**: This task also falls to Jane, as it is technical and requires intimate knowledge of the website's architecture.
#
# 10. **Social Media Integration**: Jane performs this task as it demands a fast turnaround, which she can accomplish in a single day.
#
# 11. **Quality Assurance Testing**: Both Alice Johnson and Tom Brown, the QA Engineers, split the testing responsibilities evenly to allow for thorough scrutiny of the website's features over 5 days.
#
# 12. **Client Review & Feedback**: John Doe leads this review process with the Business Owner while soliciting feedback to ensure alignment with their vision.
#
# 13. **Final Revisions**: Jane and Bob jointly address client requests by refining the website, maintaining a balance between technical builds and design tweaks.
#
# 14. **Deployment & Launch**: Jane's software expertise is crucial here as well, ensuring a smooth launch phase, supervised for any emergent issues.
#
# 15. **Post-Launch Support and Maintenance**: With Julie's ongoing involvement planned for the month, she will manage any immediate issues that arise after launch, ensuring smooth operation post-deployment.
#
# This allocation strategically balances team workloads while capitalizing on individual strengths, which will optimize the project's success and promote a collaborative environment.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0030
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         20162          12085               8077                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff',
#    'estimated_time_hours': 4.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Gather Requirements',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Wireframes',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Design UI/UX',
#    'estimated_time_hours': 64.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop Website Structure',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Coding the Frontend',
#    'estimated_time_hours': 96.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Back-end Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'User Navigation System Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO and Fast Loading Time Optimization',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Client Review & Feedback',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Final Revisions',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Deployment & Launch',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Post-Launch Support and Maintenance',
#    'estimated_time_hours': 720.0,
#    'required_resources': ['Jane Doe']}],
#  'milestones': [{'milestone_name': 'Project Kickoff',
#    'tasks': ['Project Kickoff']},
#   {'milestone_name': 'Requirements Gathering',
#    'tasks': ['Gather Requirements']},
#   {'milestone_name': 'Design Phase',
#    'tasks': ['Create Wireframes', 'Design UI/UX']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['Develop Website Structure',
#     'Coding the Frontend',
#     'Back-end Development',
#     'User Navigation System Development',
#     'SEO and Fast Loading Time Optimization',
#     'Social Media Integration']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['Quality Assurance Testing']},
#   {'milestone_name': 'Client Review', 'tasks': ['Client Review & Feedback']},
#   {'milestone_name': 'Finalization', 'tasks': ['Final Revisions']},
#   {'milestone_name': 'Launch', 'tasks': ['Deployment & Launch']},
#   {'milestone_name': 'Post-Launch Support',
#    'tasks': ['Post-Launch Support and Maintenance']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_e8016 th {
#   font-size: 120%;
# }
# #T_e8016  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_e8016" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8016_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_e8016_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_e8016_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8016_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8016_row0_col0" class="data row0 col0" >Project Kickoff</td>
#       <td id="T_e8016_row0_col1" class="data row0 col1" >4.000000</td>
#       <td id="T_e8016_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8016_row1_col0" class="data row1 col0" >Gather Requirements</td>
#       <td id="T_e8016_row1_col1" class="data row1 col1" >16.000000</td>
#       <td id="T_e8016_row1_col2" class="data row1 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8016_row2_col0" class="data row2 col0" >Create Wireframes</td>
#       <td id="T_e8016_row2_col1" class="data row2 col1" >24.000000</td>
#       <td id="T_e8016_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8016_row3_col0" class="data row3 col0" >Design UI/UX</td>
#       <td id="T_e8016_row3_col1" class="data row3 col1" >64.000000</td>
#       <td id="T_e8016_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8016_row4_col0" class="data row4 col0" >Develop Website Structure</td>
#       <td id="T_e8016_row4_col1" class="data row4 col1" >32.000000</td>
#       <td id="T_e8016_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8016_row5_col0" class="data row5 col0" >Coding the Frontend</td>
#       <td id="T_e8016_row5_col1" class="data row5 col1" >96.000000</td>
#       <td id="T_e8016_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8016_row6_col0" class="data row6 col0" >Back-end Development</td>
#       <td id="T_e8016_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_e8016_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8016_row7_col0" class="data row7 col0" >User Navigation System Development</td>
#       <td id="T_e8016_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_e8016_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8016_row8_col0" class="data row8 col0" >SEO and Fast Loading Time Optimization</td>
#       <td id="T_e8016_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_e8016_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8016_row9_col0" class="data row9 col0" >Social Media Integration</td>
#       <td id="T_e8016_row9_col1" class="data row9 col1" >8.000000</td>
#       <td id="T_e8016_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e8016_row10_col0" class="data row10 col0" >Quality Assurance Testing</td>
#       <td id="T_e8016_row10_col1" class="data row10 col1" >40.000000</td>
#       <td id="T_e8016_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e8016_row11_col0" class="data row11 col0" >Client Review & Feedback</td>
#       <td id="T_e8016_row11_col1" class="data row11 col1" >16.000000</td>
#       <td id="T_e8016_row11_col2" class="data row11 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e8016_row12_col0" class="data row12 col0" >Final Revisions</td>
#       <td id="T_e8016_row12_col1" class="data row12 col1" >24.000000</td>
#       <td id="T_e8016_row12_col2" class="data row12 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e8016_row13_col0" class="data row13 col0" >Deployment & Launch</td>
#       <td id="T_e8016_row13_col1" class="data row13 col1" >8.000000</td>
#       <td id="T_e8016_row13_col2" class="data row13 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e8016_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e8016_row14_col0" class="data row14 col0" >Post-Launch Support and Maintenance</td>
#       <td id="T_e8016_row14_col1" class="data row14 col1" >720.000000</td>
#       <td id="T_e8016_row14_col2" class="data row14 col2" >['Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_59eb7 th {
#   font-size: 120%;
# }
# #T_59eb7  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_59eb7" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59eb7_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_59eb7_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59eb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59eb7_row0_col0" class="data row0 col0" >Project Kickoff</td>
#       <td id="T_59eb7_row0_col1" class="data row0 col1" >['Project Kickoff']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59eb7_row1_col0" class="data row1 col0" >Requirements Gathering</td>
#       <td id="T_59eb7_row1_col1" class="data row1 col1" >['Gather Requirements']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59eb7_row2_col0" class="data row2 col0" >Design Phase</td>
#       <td id="T_59eb7_row2_col1" class="data row2 col1" >['Create Wireframes', 'Design UI/UX']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59eb7_row3_col0" class="data row3 col0" >Development Phase</td>
#       <td id="T_59eb7_row3_col1" class="data row3 col1" >['Develop Website Structure', 'Coding the Frontend', 'Back-end Development', 'User Navigation System Development', 'SEO and Fast Loading Time Optimization', 'Social Media Integration']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59eb7_row4_col0" class="data row4 col0" >Testing Phase</td>
#       <td id="T_59eb7_row4_col1" class="data row4 col1" >['Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_59eb7_row5_col0" class="data row5 col0" >Client Review</td>
#       <td id="T_59eb7_row5_col1" class="data row5 col1" >['Client Review & Feedback']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_59eb7_row6_col0" class="data row6 col0" >Finalization</td>
#       <td id="T_59eb7_row6_col1" class="data row6 col1" >['Final Revisions']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_59eb7_row7_col0" class="data row7 col0" >Launch</td>
#       <td id="T_59eb7_row7_col1" class="data row7 col1" >['Deployment & Launch']</td>
#     </tr>
#     <tr>
#       <th id="T_59eb7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_59eb7_row8_col0" class="data row8 col0" >Post-Launch Support</td>
#       <td id="T_59eb7_row8_col1" class="data row8 col1" >['Post-Launch Support and Maintenance']</td>
#     </tr>
#   </tbody>
# </table>
