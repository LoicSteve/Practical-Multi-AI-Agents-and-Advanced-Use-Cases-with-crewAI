# %% [markdown]
# # Building Your Crew for Production

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 228 packages in 2.54s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# openai     ------------------------------     0 B/380.41 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------     0 B/377.53 KiB
# openai     ------------------------------     0 B/380.41 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------     0 B/377.53 KiB
# openai     ------------------------------     0 B/380.41 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# networkx   ------------------------------ 14.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------     0 B/377.53 KiB
# openai     ------------------------------     0 B/380.41 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------ 14.88 KiB/1.15 MiB
# networkx   ------------------------------ 14.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------     0 B/377.53 KiB
# openai     ------------------------------     0 B/380.41 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------ 14.88 KiB/496.10 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# ipython    ------------------------------ 14.88 KiB/800.69 KiB
# pygments   ------------------------------ 14.88 KiB/1.15 MiB
# networkx   ------------------------------ 14.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 30.87 KiB/377.53 KiB
# openai     ------------------------------ 30.88 KiB/380.41 KiB
# langchain-core ------------------------------ 14.91 KiB/399.87 KiB
# watchfiles ------------------------------ 14.91 KiB/432.19 KiB
# huggingface-hub ------------------------------ 25.31 KiB/437.05 KiB
# pydantic   ------------------------------ 30.88 KiB/445.67 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 14.91 KiB/452.13 KiB
# cffi       ------------------------------ 78.15 KiB/456.29 KiB
# trio       ------------------------------ 46.92 KiB/470.44 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 46.74 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/588.29 KiB
# chromadb   ------------------------------ 14.91 KiB/603.40 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 16.00 KiB/774.15 KiB
# ipython    ------------------------------ 22.79 KiB/800.69 KiB
# langchain  ------------------------------ 14.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 16.00 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.15 MiB
# jedi       ------------------------------ 16.00 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 46.87 KiB/377.53 KiB
# openai     ------------------------------ 46.78 KiB/380.41 KiB
# langchain-core ------------------------------ 30.91 KiB/399.87 KiB
# watchfiles ------------------------------ 30.91 KiB/432.19 KiB
# huggingface-hub ------------------------------ 57.31 KiB/437.05 KiB
# pydantic   ------------------------------ 30.88 KiB/445.67 KiB
# httptools  ------------------------------ 174.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 14.91 KiB/452.13 KiB
# cffi       ------------------------------ 174.15 KiB/456.29 KiB
# trio       ------------------------------ 61.77 KiB/470.44 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 142.86 KiB/523.63 KiB
# greenlet   ------------------------------ 32.00 KiB/588.29 KiB
# chromadb   ------------------------------ 30.81 KiB/603.40 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# regex      ------------------------------ 145.25 KiB/774.15 KiB
# ipython    ------------------------------ 95.83 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 160.00 KiB/1.03 MiB
# pygments   ------------------------------ 62.67 KiB/1.15 MiB
# jedi       ------------------------------ 16.00 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 62.87 KiB/377.53 KiB
# openai     ------------------------------ 62.78 KiB/380.41 KiB
# langchain-core ------------------------------ 46.91 KiB/399.87 KiB
# watchfiles ------------------------------ 206.91 KiB/432.19 KiB
# huggingface-hub ------------------------------ 91.82 KiB/437.05 KiB
# pydantic   ------------------------------ 108.85 KiB/445.67 KiB
# httptools  ------------------------------ 238.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 24.12 KiB/452.13 KiB
# cffi       ------------------------------ 214.79 KiB/456.29 KiB
# trio       ------------------------------ 109.66 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 201.30 KiB/523.63 KiB
# greenlet   ------------------------------ 48.00 KiB/588.29 KiB
# chromadb   ------------------------------ 46.81 KiB/603.40 KiB
# pyyaml     ------------------------------ 237.39 KiB/745.07 KiB
# regex      ------------------------------ 203.11 KiB/774.15 KiB
# ipython    ------------------------------ 127.72 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 208.00 KiB/1.03 MiB
# pygments   ------------------------------ 94.37 KiB/1.15 MiB
# jedi       ------------------------------ 51.60 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 94.83 KiB/377.53 KiB
# openai     ------------------------------ 62.78 KiB/380.41 KiB
# langchain-core ------------------------------ 46.91 KiB/399.87 KiB
# watchfiles ------------------------------ 254.91 KiB/432.19 KiB
# huggingface-hub ------------------------------ 235.82 KiB/437.05 KiB
# pydantic   ------------------------------ 156.85 KiB/445.67 KiB
# httptools  ------------------------------ 270.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 24.12 KiB/452.13 KiB
# cffi       ------------------------------ 246.79 KiB/456.29 KiB
# trio       ------------------------------ 142.08 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 254.86 KiB/523.63 KiB
# greenlet   ------------------------------ 70.27 KiB/588.29 KiB
# chromadb   ------------------------------ 62.81 KiB/603.40 KiB
# pyyaml     ------------------------------ 248.15 KiB/745.07 KiB
# regex      ------------------------------ 233.46 KiB/774.15 KiB
# ipython    ------------------------------ 221.92 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 240.00 KiB/1.03 MiB
# pygments   ------------------------------ 110.37 KiB/1.15 MiB
# jedi       ------------------------------ 83.60 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 94.83 KiB/377.53 KiB
# openai     ------------------------------ 75.44 KiB/380.41 KiB
# langchain-core ------------------------------ 62.81 KiB/399.87 KiB
# watchfiles ------------------------------ 286.91 KiB/432.19 KiB
# huggingface-hub ------------------------------ 251.82 KiB/437.05 KiB
# pydantic   ------------------------------ 172.85 KiB/445.67 KiB
# httptools  ------------------------------ 305.66 KiB/449.01 KiB
# crewai-tools ------------------------------ 40.12 KiB/452.13 KiB
# cffi       ------------------------------ 302.04 KiB/456.29 KiB
# trio       ------------------------------ 158.08 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
KiB/351.99 KiB
# prompt-toolkit ------------------------------ 222.83 KiB/377.53 KiB
# openai     ------------------------------ 187.44 KiB/380.41 KiB
# langchain-core ------------------------------ 190.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 415.82 KiB/437.05 KiB
# pydantic   ------------------------------ 434.86 KiB/445.67 KiB
# crewai-tools ------------------------------ 446.91 KiB/452.13 KiB
# trio       ------------------------------ 393.65 KiB/470.44 KiB
# pytz       ------------------------------ 126.30 KiB/496.10 KiB
# greenlet   ------------------------------ 543.67 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/603.40 KiB
# pyvis      ------------------------------ 345.81 KiB/738.32 KiB
# pyyaml     ------------------------------ 582.04 KiB/745.07 KiB
# regex      ------------------------------ 521.81 KiB/774.15 KiB
# ipython    ------------------------------ 447.94 KiB/800.69 KiB
# langchain  ------------------------------ 62.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 537.81 KiB/1.03 MiB
# pygments   ------------------------------ 502.64 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (0/223)
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 78.86 KiB/350.17 KiB
# rpds-py    ------------------------------ 124.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 254.39 KiB/377.53 KiB
# openai     ------------------------------ 203.44 KiB/380.41 KiB
# langchain-core ------------------------------ 238.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 415.82 KiB/437.05 KiB
# crewai-tools ------------------------------ 446.91 KiB/452.13 KiB
# trio       ------------------------------ 397.77 KiB/470.44 KiB
# pytz       ------------------------------ 126.30 KiB/496.10 KiB
# greenlet   ------------------------------ 543.67 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/603.40 KiB
# pyvis      ------------------------------ 361.81 KiB/738.32 KiB
# pyyaml     ------------------------------ 596.82 KiB/745.07 KiB
# regex      ------------------------------ 537.81 KiB/774.15 KiB
# ipython    ------------------------------ 447.94 KiB/800.69 KiB
# langchain  ------------------------------ 62.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 553.61 KiB/1.03 MiB
# pygments   ------------------------------ 502.64 KiB/1.15 MiB
# jedi       ------------------------------ 243.60 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (0/223)
# pytest     ------------------------------     0 B/334.32 KiB
# yarl       ------------------------------ 16.00 KiB/335.82 KiB
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 110.86 KiB/350.17 KiB
# rpds-py    ------------------------------ 140.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 270.39 KiB/377.53 KiB
# openai     ------------------------------ 203.44 KiB/380.41 KiB
# langchain-core ------------------------------ 254.81 KiB/399.87 KiB
# huggingface-hub ------------------------------ 431.82 KiB/437.05 KiB
# trio       ------------------------------ 413.77 KiB/470.44 KiB
# pytz       ------------------------------ 126.30 KiB/496.10 KiB
# greenlet   ------------------------------ 559.67 KiB/588.29 KiB
# chromadb   ------------------------------ 424.56 KiB/603.40 KiB
# pyvis      ------------------------------ 377.81 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.39 KiB/745.07 KiB
# regex      ------------------------------ 569.81 KiB/774.15 KiB
# ipython    ------------------------------ 463.94 KiB/800.69 KiB
# langchain  ------------------------------ 62.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 569.81 KiB/1.03 MiB
# pygments   ------------------------------ 526.37 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (0/223)
# pytest     ------------------------------     0 B/334.32 KiB
# yarl       ------------------------------ 16.00 KiB/335.82 KiB
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 110.86 KiB/350.17 KiB
# rpds-py    ------------------------------ 156.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 286.83 KiB/377.53 KiB
# openai     ------------------------------ 203.44 KiB/380.41 KiB
# langchain-core ------------------------------ 270.81 KiB/399.87 KiB
# huggingface-hub ------------------------------ 431.82 KiB/437.05 KiB
# trio       ------------------------------ 413.77 KiB/470.44 KiB
# pytz       ------------------------------ 126.30 KiB/496.10 KiB
# greenlet   ------------------------------ 559.67 KiB/588.29 KiB
# chromadb   ------------------------------ 424.56 KiB/603.40 KiB
# pyvis      ------------------------------ 393.81 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.39 KiB/745.07 KiB
# regex      ------------------------------ 569.81 KiB/774.15 KiB
# ipython    ------------------------------ 463.94 KiB/800.69 KiB
# langchain  ------------------------------ 62.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 569.81 KiB/1.03 MiB
# pygments   ------------------------------ 526.37 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# pytest     ------------------------------     0 B/334.32 KiB
# yarl       ------------------------------ 16.00 KiB/335.82 KiB
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 126.86 KiB/350.17 KiB
# rpds-py    ------------------------------ 156.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 286.83 KiB/377.53 KiB
# openai     ------------------------------ 203.44 KiB/380.41 KiB
# langchain-core ------------------------------ 270.81 KiB/399.87 KiB
# trio       ------------------------------ 413.77 KiB/470.44 KiB
# pytz       ------------------------------ 126.30 KiB/496.10 KiB
# greenlet   ------------------------------ 559.67 KiB/588.29 KiB
# chromadb   ------------------------------ 424.56 KiB/603.40 KiB
# pyvis      ------------------------------ 393.81 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.61 KiB/745.07 KiB
# regex      ------------------------------ 569.81 KiB/774.15 KiB
# ipython    ------------------------------ 479.60 KiB/800.69 KiB
# langchain  ------------------------------ 78.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 569.81 KiB/1.03 MiB
# pygments   ------------------------------ 526.37 KiB/1.15 MiB
# jedi       ------------------------------ 243.60 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# protobuf   ------------------------------ 32.00 KiB/309.20 KiB
# jiter      ------------------------------ 30.92 KiB/317.86 KiB
# pytest     ------------------------------ 52.14 KiB/334.32 KiB
# yarl       ------------------------------ 64.00 KiB/335.82 KiB
# tzdata     ------------------------------ 32.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 171.81 KiB/350.17 KiB
# rpds-py    ------------------------------ 204.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 318.83 KiB/377.53 KiB
# openai     ------------------------------ 219.44 KiB/380.41 KiB
# langchain-core ------------------------------ 302.91 KiB/399.87 KiB
# trio       ------------------------------ 445.77 KiB/470.44 KiB
# pytz       ------------------------------ 142.30 KiB/496.10 KiB
# greenlet   ------------------------------ 575.67 KiB/588.29 KiB
# chromadb   ------------------------------ 456.37 KiB/603.40 KiB
# pyvis      ------------------------------ 438.59 KiB/738.32 KiB
# pyyaml     ------------------------------ 669.39 KiB/745.07 KiB
# regex      ------------------------------ 617.81 KiB/774.15 KiB
# ipython    ------------------------------ 517.57 KiB/800.69 KiB
# langchain  ------------------------------ 94.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 633.81 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# protobuf   ------------------------------ 62.73 KiB/309.20 KiB
# jiter      ------------------------------ 62.92 KiB/317.86 KiB
# pytest     ------------------------------ 77.43 KiB/334.32 KiB
# yarl       ------------------------------ 96.00 KiB/335.82 KiB
# tzdata     ------------------------------ 63.40 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 203.81 KiB/350.17 KiB
# rpds-py    ------------------------------ 236.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 350.83 KiB/377.53 KiB
# openai     ------------------------------ 219.44 KiB/380.41 KiB
# langchain-core ------------------------------ 334.81 KiB/399.87 KiB
# pytz       ------------------------------ 142.30 KiB/496.10 KiB
# greenlet   ------------------------------ 588.29 KiB/588.29 KiB
# chromadb   ------------------------------ 472.56 KiB/603.40 KiB
# pyvis      ------------------------------ 455.85 KiB/738.32 KiB
# pyyaml     ------------------------------ 701.39 KiB/745.07 KiB
# regex      ------------------------------ 649.81 KiB/774.15 KiB
# ipython    ------------------------------ 575.94 KiB/800.69 KiB
# langchain  ------------------------------ 94.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 665.81 KiB/1.03 MiB
# pygments   ------------------------------ 638.37 KiB/1.15 MiB
# jedi       ------------------------------ 259.60 KiB/1.50 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# langsmith  ------------------------------     0 B/304.00 KiB
# protobuf   ------------------------------ 78.73 KiB/309.20 KiB
# jiter      ------------------------------ 78.92 KiB/317.86 KiB
# pytest     ------------------------------ 93.43 KiB/334.32 KiB
# yarl       ------------------------------ 128.00 KiB/335.82 KiB
# tzdata     ------------------------------ 76.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 217.48 KiB/350.17 KiB
# rpds-py    ------------------------------ 268.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 366.83 KiB/377.53 KiB
# openai     ------------------------------ 219.44 KiB/380.41 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 142.30 KiB/496.10 KiB
# chromadb   ------------------------------ 472.56 KiB/603.40 KiB
# pyvis      ------------------------------ 487.85 KiB/738.32 KiB
# pyyaml     ------------------------------ 717.39 KiB/745.07 KiB
# regex      ------------------------------ 681.81 KiB/774.15 KiB
# ipython    ------------------------------ 575.94 KiB/800.69 KiB
# langchain  ------------------------------ 110.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 681.81 KiB/1.03 MiB
# pygments   ------------------------------ 670.37 KiB/1.15 MiB
# jedi       ------------------------------ 259.60 KiB/1.50 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# langsmith  ------------------------------     0 B/304.00 KiB
# protobuf   ------------------------------ 78.73 KiB/309.20 KiB
# jiter      ------------------------------ 78.92 KiB/317.86 KiB
# pytest     ------------------------------ 93.43 KiB/334.32 KiB
# yarl       ------------------------------ 128.00 KiB/335.82 KiB
# tzdata     ------------------------------ 76.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 217.48 KiB/350.17 KiB
# rpds-py    ------------------------------ 268.58 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 366.83 KiB/377.53 KiB
# openai     ------------------------------ 235.44 KiB/380.41 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 142.30 KiB/496.10 KiB
# chromadb   ------------------------------ 472.56 KiB/603.40 KiB
# pyvis      ------------------------------ 487.85 KiB/738.32 KiB
# pyyaml     ------------------------------ 717.39 KiB/745.07 KiB
# regex      ------------------------------ 681.81 KiB/774.15 KiB
# ipython    ------------------------------ 591.94 KiB/800.69 KiB
# langchain  ------------------------------ 110.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 681.81 KiB/1.03 MiB
# pygments   ------------------------------ 670.37 KiB/1.15 MiB
# jedi       ------------------------------ 259.60 KiB/1.50 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# langsmith  ------------------------------ 16.00 KiB/304.00 KiB
# protobuf   ------------------------------ 110.73 KiB/309.20 KiB
# jiter      ------------------------------ 94.92 KiB/317.86 KiB
# pytest     ------------------------------ 109.43 KiB/334.32 KiB
# yarl       ------------------------------ 144.00 KiB/335.82 KiB
# tzdata     ------------------------------ 76.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 233.48 KiB/350.17 KiB
# rpds-py    ------------------------------ 284.58 KiB/351.99 KiB
# openai     ------------------------------ 235.44 KiB/380.41 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 158.40 KiB/496.10 KiB
# chromadb   ------------------------------ 472.56 KiB/603.40 KiB
# pyvis      ------------------------------ 498.70 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.39 KiB/745.07 KiB
# regex      ------------------------------ 697.81 KiB/774.15 KiB
# ipython    ------------------------------ 623.94 KiB/800.69 KiB
# langchain  ------------------------------ 110.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 697.81 KiB/1.03 MiB
# pygments   ------------------------------ 724.86 KiB/1.15 MiB
# jedi       ------------------------------ 259.60 KiB/1.50 MiB
# aiohttp    ------------------------------ 751.04 KiB/1.60 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# pypdf      ------------------------------ 15.89 KiB/290.99 KiB
# langsmith  ------------------------------ 16.00 KiB/304.00 KiB
# protobuf   ------------------------------ 126.73 KiB/309.20 KiB
# jiter      ------------------------------ 110.92 KiB/317.86 KiB
# pytest     ------------------------------ 141.43 KiB/334.32 KiB
# yarl       ------------------------------ 160.00 KiB/335.82 KiB
# tzdata     ------------------------------ 76.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 241.19 KiB/350.17 KiB
# rpds-py    ------------------------------ 300.58 KiB/351.99 KiB
# openai     ------------------------------ 235.44 KiB/380.41 KiB
# langchain-core ------------------------------ 366.91 KiB/399.87 KiB
# pytz       ------------------------------ 158.40 KiB/496.10 KiB
# chromadb   ------------------------------ 488.56 KiB/603.40 KiB
# pyvis      ------------------------------ 505.81 KiB/738.32 KiB
# regex      ------------------------------ 729.48 KiB/774.15 KiB
# ipython    ------------------------------ 623.94 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 729.81 KiB/1.03 MiB
# pygments   ------------------------------ 766.37 KiB/1.15 MiB
# jedi       ------------------------------ 275.60 KiB/1.50 MiB
# aiohttp    ------------------------------ 767.04 KiB/1.60 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------     0 B/272.08 KiB
# pypdf      ------------------------------ 31.89 KiB/290.99 KiB
# langsmith  ------------------------------ 32.00 KiB/304.00 KiB
# protobuf   ------------------------------ 142.73 KiB/309.20 KiB
# jiter      ------------------------------ 126.92 KiB/317.86 KiB
# pytest     ------------------------------ 157.43 KiB/334.32 KiB
# yarl       ------------------------------ 192.00 KiB/335.82 KiB
# tzdata     ------------------------------ 92.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 269.52 KiB/350.17 KiB
# rpds-py    ------------------------------ 316.58 KiB/351.99 KiB
# openai     ------------------------------ 235.44 KiB/380.41 KiB
# langchain-core ------------------------------ 382.91 KiB/399.87 KiB
# pytz       ------------------------------ 158.40 KiB/496.10 KiB
# chromadb   ------------------------------ 488.56 KiB/603.40 KiB
# pyvis      ------------------------------ 521.81 KiB/738.32 KiB
# regex      ------------------------------ 745.48 KiB/774.15 KiB
# ipython    ------------------------------ 639.94 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 745.81 KiB/1.03 MiB
# pygments   ------------------------------ 798.37 KiB/1.15 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 16.00 KiB/272.08 KiB
# pypdf      ------------------------------ 31.89 KiB/290.99 KiB
# langsmith  ------------------------------ 48.00 KiB/304.00 KiB
# protobuf   ------------------------------ 158.73 KiB/309.20 KiB
# jiter      ------------------------------ 142.92 KiB/317.86 KiB
# pytest     ------------------------------ 157.43 KiB/334.32 KiB
# yarl       ------------------------------ 192.00 KiB/335.82 KiB
# tzdata     ------------------------------ 92.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 269.52 KiB/350.17 KiB
# rpds-py    ------------------------------ 332.58 KiB/351.99 KiB
# openai     ------------------------------ 235.44 KiB/380.41 KiB
# pytz       ------------------------------ 158.40 KiB/496.10 KiB
# chromadb   ------------------------------ 488.56 KiB/603.40 KiB
# pyvis      ------------------------------ 537.81 KiB/738.32 KiB
# regex      ------------------------------ 745.48 KiB/774.15 KiB
# ipython    ------------------------------ 639.94 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 745.81 KiB/1.03 MiB
# pygments   ------------------------------ 802.68 KiB/1.15 MiB
# jedi       ------------------------------ 275.60 KiB/1.50 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# qdrant-client ------------------------------ 14.91 KiB/260.91 KiB
# frozenlist ------------------------------ 48.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 44.48 KiB/272.08 KiB
# pypdf      ------------------------------ 64.00 KiB/290.99 KiB
# langsmith  ------------------------------ 96.00 KiB/304.00 KiB
# protobuf   ------------------------------ 190.73 KiB/309.20 KiB
# jiter      ------------------------------ 174.92 KiB/317.86 KiB
# pytest     ------------------------------ 189.43 KiB/334.32 KiB
# yarl       ------------------------------ 224.00 KiB/335.82 KiB
# tzdata     ------------------------------ 92.66 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 282.17 KiB/350.17 KiB
# openai     ------------------------------ 251.44 KiB/380.41 KiB
# pytz       ------------------------------ 174.40 KiB/496.10 KiB
# chromadb   ------------------------------ 508.13 KiB/603.40 KiB
# pyvis      ------------------------------ 569.81 KiB/738.32 KiB
# regex      ------------------------------ 774.15 KiB/774.15 KiB
# ipython    ------------------------------ 655.94 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/982.35 KiB
# tiktoken   ------------------------------ 776.44 KiB/1.03 MiB
# pygments   ------------------------------ 830.37 KiB/1.15 MiB
# jedi       ------------------------------ 275.60 KiB/1.50 MiB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (5/223)
# qdrant-client ------------------------------ 14.91 KiB/260.91 KiB
# frozenlist ------------------------------ 48.00 KiB/268.43 KiB
# ...
# uv         ------------------------------ 12.00 MiB/13.80 MiB
# numpy      ------------------------------ 11.57 MiB/17.41 MiB
# lancedb    ------------------------------ 11.55 MiB/26.09 MiB
# pylance    ------------------------------ 11.16 MiB/29.11 MiB
# numpy      ------------------------------ 13.88 MiB/17.41 MiB
# lancedb    ------------------------------ 14.30 MiB/26.09 MiB
# pylance    ------------------------------ 15.23 MiB/29.11 MiB
# ⠙ Preparing packages... (217/223) 13.06 MiB/38.22 MiB
# pandas     ------------------------------ 10.92 MiB/12.45 MiB
# numpy      ------------------------------ 13.88 MiB/17.41 MiB
# lancedb    ------------------------------ 14.89 MiB/26.09 MiB
# pylance    ------------------------------ 15.36 MiB/29.11 MiB
# ⠙ Preparing packages... (217/223) 13.11 MiB/38.22 MiB
# pandas     ------------------------------ 11.05 MiB/12.45 MiB
# numpy      ------------------------------ 13.88 MiB/17.41 MiB
# lancedb    ------------------------------ 15.19 MiB/26.09 MiB
# pylance    ------------------------------ 16.19 MiB/29.11 MiB
# ⠹ Preparing packages... (218/223) 14.11 MiB/38.22 MiB
# pandas     ------------------------------ 11.17 MiB/12.45 MiB
# numpy      ------------------------------ 13.88 MiB/17.41 MiB
# lancedb    ------------------------------ 16.64 MiB/26.09 MiB
# pylance    ------------------------------ 17.52 MiB/29.11 MiB
# ⠹ Preparing packages... (218/223) 15.57 MiB/38.22 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# numpy      ------------------------------ 13.88 MiB/17.41 MiB
# lancedb    ------------------------------ 18.79 MiB/26.09 MiB
# pylance    ------------------------------ 18.26 MiB/29.11 MiB
# ⠹ Preparing packages... (218/223) 16.48 MiB/38.22 MiB
# pandas     ------------------------------ 11.53 MiB/12.45 MiB
# numpy      ------------------------------ 14.92 MiB/17.41 MiB
# lancedb    ------------------------------ 19.42 MiB/26.09 MiB
# pylance    ------------------------------ 19.57 MiB/29.11 MiB
# ⠹ Preparing packages... (218/223) 17.55 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# numpy      ------------------------------ 15.88 MiB/17.41 MiB
# lancedb    ------------------------------ 20.27 MiB/26.09 MiB
# pylance    ------------------------------ 20.58 MiB/29.11 MiB
# ⠸ Preparing packages... (218/223) 18.44 MiB/38.22 MiB
# pandas     ------------------------------ 11.91 MiB/12.45 MiB
# numpy      ------------------------------ 17.16 MiB/17.41 MiB
# lancedb    ------------------------------ 20.27 MiB/26.09 MiB
# pylance    ------------------------------ 20.58 MiB/29.11 MiB
# ⠸ Preparing packages... (218/223) 19.77 MiB/38.22 MiB
# pandas     ------------------------------ 12.32 MiB/12.45 MiB
# numpy      ------------------------------ 17.36 MiB/17.41 MiB
# lancedb    ------------------------------ 20.27 MiB/26.09 MiB
# pylance    ------------------------------ 20.58 MiB/29.11 MiB
# ⠸ Preparing packages... (218/223) 20.39 MiB/38.22 MiB
# pandas     ------------------------------ 12.32 MiB/12.45 MiB
# numpy      ------------------------------ 17.37 MiB/17.41 MiB
# lancedb    ------------------------------ 20.27 MiB/26.09 MiB
# pylance    ------------------------------ 20.58 MiB/29.11 MiB
# ⠸ Preparing packages... (218/223) 20.39 MiB/38.22 MiB
# pandas     ------------------------------ 12.32 MiB/12.45 MiB
# lancedb    ------------------------------ 20.27 MiB/26.09 MiB
# ⠇ Preparing packages... (221/223) 36.90 MiB/38.22 MiB
# pylance    ------------------------------ 27.11 MiB/29.11 MiB
# ⠇ Preparing packages... (221/223) 36.90 MiB/38.22 MiB
# ⠋ Preparing packages... (222/223) 36.90 MiB/38.22 MiB
# ⠋ Preparing packages... (222/223) 36.90 MiB/38.22 MiB
# ⠋ Preparing packages... (222/223) 36.91 MiB/38.22 MiB
# ⠋ Preparing packages... (222/223) 36.93 MiB/38.22 MiB
# ⠋ Preparing packages... (222/223) 36.96 MiB/38.22 MiB
# Prepared 223 packages in 7.10s
# Installed 223 packages in 225ms
#  + aiohappyeyeballs==2.4.3
#  + aiohttp==3.11.7
#  + aiosignal==1.3.1
#  + alembic==1.14.0
#  + annotated-types==0.7.0
#  + anyio==4.6.2.post1
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==2.4.1
#  + attrs==24.2.0
#  + auth0-python==4.7.2
#  + backoff==2.2.1
#  + bcrypt==4.2.1
#  + beautifulsoup4==4.12.3
#  + build==1.2.2.post1
#  + cachetools==5.5.0
#  + certifi==2024.8.30
#  + cffi==1.17.1
#  + charset-normalizer==3.4.0
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.20
#  + click==8.1.7
#  + cohere==5.11.4
#  + coloredlogs==15.0.1
#  + crewai==0.83.0
#  + crewai-tools==0.14.0
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.15
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.125
#  + et-xmlfile==2.0.0
#  + executing==2.1.0
#  + fastapi==0.115.5
#  + fastavro==1.9.7
#  + filelock==3.16.1
#  + flatbuffers==24.3.25
#  + frozenlist==1.5.0
#  + fsspec==2024.10.0
#  + google-api-core==2.23.0
#  + google-auth==2.36.0
#  + google-cloud-aiplatform==1.73.0
#  + google-cloud-bigquery==3.27.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.13.1
#  + google-cloud-storage==2.18.2
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.66.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.13.1
#  + grpcio==1.68.0
#  + grpcio-status==1.68.0
#  + grpcio-tools==1.68.0
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.0.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.26.2
#  + humanfriendly==10.0
#  + hyperframe==6.0.1
#  + idna==3.10
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.4.5
#  + iniconfig==2.0.0
#  + instructor==1.6.4
#  + ipython==8.29.0
#  + jedi==0.19.2
#  + jinja2==3.1.4
#  + jiter==0.6.1
#  + json-repair==0.30.2
#  + jsonpatch==1.33
#  + jsonpickle==4.0.0
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==31.0.0
#  + lancedb==0.16.0
#  + langchain==0.3.8
#  + langchain-cohere==0.3.2
#  + langchain-community==0.3.4
#  + langchain-core==0.3.21
#  + langchain-experimental==0.3.3
#  + langchain-openai==0.2.10
#  + langchain-text-splitters==0.3.2
#  + langsmith==0.1.146
#  + litellm==1.52.16
#  + mako==1.3.6
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.23.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.33
#  + mmh3==5.0.1
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.55.1
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.28.2
#  + opentelemetry-exporter-otlp-proto-common==1.28.2
#  + opentelemetry-exporter-otlp-proto-grpc==1.28.2
#  + opentelemetry-exporter-otlp-proto-http==1.28.2
#  + opentelemetry-instrumentation==0.49b2
#  + opentelemetry-instrumentation-asgi==0.49b2
#  + opentelemetry-instrumentation-fastapi==0.49b2
#  + opentelemetry-proto==1.28.2
#  + opentelemetry-sdk==1.28.2
#  + opentelemetry-semantic-conventions==0.49b2
#  + opentelemetry-util-http==0.49b2
#  + orjson==3.10.12
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parameterized==0.9.0
#  + parso==0.8.4
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.4
#  + pexpect==4.9.0
#  + pillow==11.0.0
#  + pluggy==1.5.0
#  + portalocker==2.10.1
#  + posthog==3.7.3
#  + prompt-toolkit==3.0.48
#  + propcache==0.2.0
#  + proto-plus==1.25.0
#  + protobuf==5.28.3
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==18.1.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.2
#  + pydantic-core==2.27.1
#  + pydantic-settings==2.6.1
#  + pygments==2.18.0
#  + pyjwt==2.10.0
#  + pylance==0.19.2
#  + pypdf==5.1.0
#  + pypdfium2==4.30.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.389
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + pytest==8.3.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.12.1
#  + referencing==0.35.1
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.21.0
#  + rsa==4.9
#  + schema==0.7.7
#  + selenium==4.27.1
#  + setuptools==75.6.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.16.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + sqlalchemy==2.0.36
#  + stack-data==0.6.3
#  + starlette==0.41.3
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.1.0
#  + tomli-w==1.1.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + trio==0.27.0
#  + trio-websocket==0.11.1
#  + typer==0.13.1
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2024.2
#  + urllib3==2.2.3
#  + uv==0.5.4
#  + uvicorn==0.32.1
#  + uvloop==0.21.0
#  + watchfiles==1.0.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==14.1
#  + wrapt==1.17.0
#  + wsproto==1.2.0
#  + yarl==1.18.0
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Emergence of Multimodal Models**: In 2024, notable advancements have been made in multimodal LLMs that can process and integrate multiple forms of data such as text, images, and audio, leading to more complex and richer content generation.
#
# 2. **OpenAI's latest releases**: OpenAI has launched new versions of their LLMs that significantly improve contextual comprehension and response relevance, including better handling of nuanced queries and less reliance on prompts.
#
# 3. **Enhanced Fine-Tuning Techniques**: Research indicates the increasing effectiveness of fine-tuning methodologies that allow LLMs to be specialized for particular applications without extensive retraining data, improving performance in specific domains like healthcare and finance.
#
# 4. **AI Safety and Ethics Frameworks**: 2024 has seen a stronger emphasis on the establishment of robust ethical guidelines and safety protocols for deploying LLMs, including measures to mitigate bias and reduce harmful outputs through advanced moderation systems.
#
# 5. **Integration into Collaborative Tools**: Major tech companies have begun integrating LLMs into productivity and collaboration software (like Google Workspace and Microsoft 365), enhancing users’ ability to draft, edit, and brainstorm ideas efficiently.
#
# 6. **Increased Compute Efficiency**: The development of novel algorithms and architectures, such as sparse transformers, has led to LLMs that are not only more efficient in computation but also less energy-consuming, promoting sustainability in AI practices.
#
# 7. **Personalization Capabilities**: AI research in 2024 has focused on personalization within LLMs, allowing models to tailor responses based on user preferences and behavior, thus enhancing user engagement and satisfaction.
#
# 8. **Regulatory Developments**: Various governments and international bodies are progressing in formulating regulations specifically targeting the deployment of AI LLMs, ensuring compliance with data protection and privacy laws as LLMs become more widespread.
#
# 9. **Research & Development Initiatives**: Major academic and corporate partnerships are catalyzing breakthroughs in LLM research, accelerating innovations in natural language understanding and machine reasoning capabilities that were previously unattainable.
#
# 10. **Community-Led Open-source Projects**: A resurgence of community-driven open-source initiatives has led to the creation of new LLM models that are more transparent and readily accessible, allowing a wider range of developers and organizations to utilize powerful NLP tools without heavy financial burdens.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Report on the Current Landscape of AI LLMs in 2024
#
# ## 1. Emergence of Multimodal Models
# In 2024, the advancement of multimodal large language models (LLMs) marks a significant milestone in the evolution of AI technologies. These models are engineered to process and harmonize a variety of data types including text, images, and audio. By integrating these modalities, multimodal LLMs facilitate a more comprehensive understanding of context, leading to the generation of richer and more layered content. Applications ranging from interactive educational tools to sophisticated content creation platforms benefit from this capability. This multi-faceted approach allows for more nuanced interactions and outputs, enhancing user engagement and effectiveness in communication.
#
# ## 2. OpenAI's Latest Releases
# OpenAI has garnered significant attention in 2024 with the launch of new versions of their LLMs, showcasing marked improvements in contextual comprehension and the relevance of their responses. These updates demonstrate a decreased dependency on specific prompts, as the models can effectively manage more nuanced queries to produce logically coherent and contextually accurate replies. The robustness of the models enables users to obtain high-quality responses even in complex scenarios, thus broadening the potential applications of OpenAI's offerings in areas like customer service, creative writing, and information retrieval.
#
# ## 3. Enhanced Fine-Tuning Techniques
# The capacity for enhanced fine-tuning techniques is becoming critical as AI LLMs embrace specialization for niche applications. Research from 2024 indicates that these methods allow for effective adaptations to specific fields—such as healthcare and finance—without necessitating vast amounts of retraining data. As a result, performance benchmarks in these domains have shown considerable improvement. Fine-tuning now incorporates advanced algorithms that refine model behavior based on domain-specific terminologies and contextual knowledge, leading to high-accuracy results and relevant insights.
#
# ## 4. AI Safety and Ethics Frameworks
# This year has seen a pivotal shift towards prioritizing ethics and safety in the deployment of LLMs. Organizations are developing robust ethical frameworks aimed at reducing biases and preventing outputs that could be considered harmful or offensive. These frameworks include advanced moderation systems and accountability measures that strive to ensure responsible AI usage. As LLMs continue gaining traction across various applications, establishing clear standards for ethical conduct has become paramount for maintaining user trust and safeguarding societal values.
#
# ## 5. Integration into Collaborative Tools
# The integration of LLMs into productivity and collaborative software suites, such as Google Workspace and Microsoft 365, has fundamentally transformed the way users interact with these tools. In 2024, LLMs are utilized to help users draft, edit, and brainstorm with remarkable efficiency. These integrations harness the power of LLMs to reduce the cognitive load on users, enabling seamless collaboration and creativity. Enhanced features, such as intelligent suggestions and contextual edits, ensure a streamlined workflow, making these tools indispensable for both individual users and teams.
#
# ## 6. Increased Compute Efficiency
# Significant developments in algorithms and architectures, notably sparse transformers, have revolutionized compute efficiency for LLMs. In 2024, these advancements allow for LLMs that not only perform tasks faster but also consume less energy, aligning with the global push for sustainability in technology. Through improved resource management and optimization techniques, developers can deploy AI models that are both powerful and environmentally conscious. This approach not only enhances operational capabilities but also addresses concerns regarding the environmental impact of extensive AI deployments.
#
# ## 7. Personalization Capabilities
# The trend towards personalization in AI LLMs has gained momentum in 2024, with research focusing on tailoring responses according to individual user preferences and behavior patterns. This capability heightens user engagement by creating a more relatable and satisfying interaction experience. By leveraging user data responsibly, LLMs can adjust their outputs based on previous interactions, resulting in recommendations and responses that resonate more personally with users. This evolution in personalization contributes to a deeper connection between users and AI systems, enhancing overall satisfaction and efficiency.
#
# ## 8. Regulatory Developments
# As AI LLMs proliferate in various sectors, regulatory frameworks are evolving to address the unique challenges posed by these technologies. Governments and international bodies are making strides to formulate comprehensive regulations that ensure compliance with data protection and privacy laws. These regulations are crucial in safeguarding user information while promoting transparency in AI applications. By establishing clear guidelines, stakeholders can better navigate the complexities of deploying LLMs within legal and ethical boundaries.
#
# ## 9. Research & Development Initiatives
# The landscape of LLM research is being transformed by collaborations between academic institutions and corporate entities. In 2024, joint initiatives are catalyzing breakthroughs in natural language understanding and machine reasoning capabilities, paving the way for innovations that were once seen as infeasible. This synergy promotes a dynamic exchange of ideas and resources, enhancing the pace of progress in AI technologies. With significant investments in R&D, stakeholders are positioned to push the boundaries of what is achievable in the field of LLMs.
#
# ## 10. Community-Led Open-source Projects
# A renewed focus on community-driven open-source projects in 2024 has facilitated the inception of innovative LLM models that prioritize transparency and accessibility. These initiatives empower developers and organizations, large and small, to leverage powerful natural language processing (NLP) tools without incurring exorbitant costs. By fostering an environment of collaboration and shared knowledge, the open-source community is expanding the reach of AI technologies, democratizing access, and enabling more diverse applications across industries.
#
# This comprehensive report outlines the significant advancements and trends shaping the AI LLM landscape in 2024. Stakeholders are encouraged to consider these developments to inform strategic decisions and enhancements in AI applications.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
